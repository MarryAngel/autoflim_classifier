# %%
# Libraries and configurations
import sys
from pathlib import Path
import json

# PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models
from torchvision import transforms
from torchinfo import summary

# Visualization and analysis
import os
import seaborn as sns
import PIL
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import cohen_kappa_score

# %%
# Adds the project root to the path
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))
print(f"Project root added to path: {project_root}")

# from config import (
#     get_dataset_paths
# )
# Out:
# Project root added to path: /home/maria/Documents/flim_classification/baseline_networks

# %%
from src.dataset import DataModuleParasite
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from src.dataset import DataModuleParasite
#
# File ~/Documents/flim_classification/baseline_networks/src/dataset.py:8
#       3 from PIL import Image
#       5 # from flim_classification.baseline_networks.config_rmv import get_dataset_paths
#       6 # from flim_classification.baseline_networks.config_rmv import get_split_path_incremental
# ----> 8 from flim_classification.config import get_dataset_paths, get_split_path_incremental
#      10 from torch.utils.data import Dataset, DataLoader
#      12 def pil_loader(image_path):
#
# ModuleNotFoundError: No module named 'flim_classification'

# %%
from src.dataset import DataModuleParasite
from src import utils
from src import models
from src import trainer

# %%
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
