# %%
# Libraries and configurations
import sys
from pathlib import Path
import json

# PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models
from torchvision import transforms
from torchinfo import summary

# Visualization and analysis
import os
import seaborn as sns
import PIL
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import cohen_kappa_score

# Adds the project root to the path
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

from config import (
    get_dataset_paths
)

from src.dataset import DataModuleParasite
from src import utils
from src import models
from src import trainer

seed = 42
torch.manual_seed(seed)
np.random.seed(seed)

# %% [markdown]
# ### Eggs: Trained from Scratch

# %%
# Configuration for Eggs Dataset

CONFIG_EGG = {
    'dataset_name': 'eggs',
    'split': [1, 2, 3],
    # 'percentage': [1, 5, 25, 50, 75, 100],
    'percentage': [1, 5, 50, 100],
    'num_classes': 9,
    'batch_size': 16,
    'num_workers': 4,
    'image_size': 200,
    'lr': 1e-4,
    'num_epochs': 100,
    'device': 'cuda' if torch.cuda.is_available() else 'cpu'
}

# Create dataloaders
dataset_name = CONFIG_EGG['dataset_name']
model_name = 'mobilenetv2_scratch'
type_model = 'mobilenetv2'
pre_trained = False
path = f"{model_name}/{dataset_name}"
config = CONFIG_EGG
dataloaders = {}

transforms_egg = transforms.Compose([
    transforms.Resize((config['image_size'], config['image_size'])),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

dataloaders = utils.create_dataloaders(config=config, transforms=transforms_egg)

model_scratch, _, _, _ = models.create_model(type_model=type_model, description_path=f"{path}/{model_name}_model_params_{dataset_name}.txt", config=config, pre_trained=pre_trained)

n_flops, n_params = utils.count_flops(model_scratch, input_size=(1, 3, config['image_size'], config['image_size']))
print(f"Model: {model_name} - Dataset: {dataset_name}")
print(f"FLOPs: {n_flops} FLOPs")
print(f"Parameters: {n_params} ")
# Out:
# Model: mobilenetv2_scratch - Dataset: eggs
# FLOPs: 283392976.0 FLOPs
# Parameters: 2235401.0

# %%
# Training loop with pre-trained weights
historic_train = trainer.train_loop(config, dataloaders, path, dataset_name, model_name=model_name, type_model=type_model, pre_trained=pre_trained)

# Save training history
with open(f'{path}/{model_name}_historic_{config["dataset_name"]}.json', 'w') as f:
    json.dump(historic_train, f)
# Out:
# Early stopping at epoch 21 for split 1 and percentage 1%
# Early stopping at epoch 22 for split 2 and percentage 1%
# Early stopping at epoch 21 for split 3 and percentage 1%
# Early stopping at epoch 24 for split 1 and percentage 5%
# Early stopping at epoch 23 for split 2 and percentage 5%
# Early stopping at epoch 24 for split 3 and percentage 5%
# Early stopping at epoch 81 for split 1 and percentage 50%
# Early stopping at epoch 33 for split 3 and percentage 50%
# Early stopping at epoch 42 for split 1 and percentage 100%
# Early stopping at epoch 35 for split 2 and percentage 100%
# Early stopping at epoch 31 for split 3 and percentage 100%

# %%
utils.loss_and_accuracy_split(config, path, model_name, show_plot=False)
utils.loss_and_accuracy_aggregate(config, path, model_name, show_plot=False)

results_test = utils.evaluate_test_set(config, path, model_name, dataloaders, type_model=type_model, pre_trained=pre_trained)  

# Save results to JSON
with open(f'{path}/{model_name}_test_results_{config["dataset_name"]}.json', 'w') as f:
    json.dump(results_test, f)

utils.calculate_and_save_reports(config, path, model_name)
# Out:
# Aggregated classification reports saved to mobilenetv2_scratch/eggs/mobilenetv2_scratch_aggregated_classification_report_eggs.txt

# %% [markdown]
# ### Larvae: Trained from Scratch

# %%
# Configuration for Larvae Dataset
CONFIG_LARVAE = {
    'dataset_name': 'larvae',
    'split': [1,2,3],
    'percentage': [1, 5, 25, 50, 75, 100],
    'num_classes': 2,
    'batch_size': 16,
    'num_workers': 4,
    'image_size': 200,
    'lr': 1e-4,
    'num_epochs': 100,
    'device': 'cuda' if torch.cuda.is_available() else 'cpu'
}

# Create dataloaders
dataset_name = CONFIG_LARVAE['dataset_name']
model_name = 'mobilenetv2_scratch'
type_model = 'mobilenetv2'
pre_trained = False
path = f"{model_name}/{dataset_name}"
config = CONFIG_LARVAE
dataloaders = {}

transforms_larvae = transforms.Compose([
    transforms.Resize((config['image_size'], config['image_size'])),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

dataloaders = utils.create_dataloaders(config=config, transforms=transforms_larvae)

model_scratch, _, _, _ = models.create_model(type_model=type_model, description_path=f"{path}/{model_name}_model_params_{dataset_name}.txt", config=config, pre_trained=pre_trained)

n_flops, n_params = utils.count_flops(model_scratch, input_size=(1, 3, config['image_size'], config['image_size']))
print(f"Model: {model_name} - Dataset: {dataset_name}")
print(f"FLOPs: {n_flops} FLOPs")
print(f"Parameters: {n_params} ")
# Out:
# Model: mobilenetv2_scratch - Dataset: larvae
# FLOPs: 283384016.0 FLOPs
# Parameters: 2226434.0

# %%
# Training loop with pre-trained weights
historic_train = trainer.train_loop(config, dataloaders, path, dataset_name, model_name=model_name, type_model=type_model, pre_trained=pre_trained)

# Save training history
with open(f'{path}/{model_name}_historic_{config["dataset_name"]}.json', 'w') as f:
    json.dump(historic_train, f)
# Out:
# Early stopping at epoch 22 for split 1 and percentage 1%
# Early stopping at epoch 21 for split 2 and percentage 1%
# Early stopping at epoch 21 for split 3 and percentage 1%
# Early stopping at epoch 41 for split 1 and percentage 5%
# Early stopping at epoch 57 for split 2 and percentage 5%
# Early stopping at epoch 75 for split 3 and percentage 5%
# Early stopping at epoch 57 for split 1 and percentage 25%
# Early stopping at epoch 25 for split 2 and percentage 25%
# Early stopping at epoch 42 for split 3 and percentage 25%
# Early stopping at epoch 31 for split 1 and percentage 50%
# Early stopping at epoch 27 for split 2 and percentage 50%
# Early stopping at epoch 54 for split 3 and percentage 50%
# Early stopping at epoch 82 for split 1 and percentage 75%
# Early stopping at epoch 55 for split 2 and percentage 75%
# Early stopping at epoch 51 for split 3 and percentage 75%
# Early stopping at epoch 55 for split 1 and percentage 100%
# Early stopping at epoch 85 for split 2 and percentage 100%
# Early stopping at epoch 60 for split 3 and percentage 100%

# %%
utils.loss_and_accuracy_split(config, path, model_name, show_plot=False)
utils.loss_and_accuracy_aggregate(config, path, model_name, show_plot=False)

results_test = utils.evaluate_test_set(config, path, model_name, dataloaders, type_model=type_model, pre_trained=pre_trained)  

# Save results to JSON
with open(f'{path}/{model_name}_test_results_{config["dataset_name"]}.json', 'w') as f:
    json.dump(results_test, f)

utils.calculate_and_save_reports(config, path, model_name)
# Out:
# Aggregated classification reports saved to mobilenetv2_scratch/larvae/mobilenetv2_scratch_aggregated_classification_report_larvae.txt

# %% [markdown]
# ### Cysts: Trained from Scratch

# %%
# Configuration for Cisto Dataset
CONFIG_CISTO = {
    'dataset_name': 'cistos',
    'split': [1, 2, 3],
    'percentage': [1, 5, 25, 50, 75, 100],
    'num_classes': 7,
    'batch_size': 16,
    'num_workers': 4,
    'image_size': 200,
    'lr': 1e-4,
    'num_epochs': 100,
    'device': 'cuda' if torch.cuda.is_available() else 'cpu'
}

# Create dataloaders
dataset_name = CONFIG_CISTO['dataset_name']
model_name = 'mobilenetv2_scratch'
type_model = 'mobilenetv2'
pre_trained = False
path = f"{model_name}/{dataset_name}"
config = CONFIG_CISTO
dataloaders = {}

transforms_cistos = transforms.Compose([
    transforms.Resize((config['image_size'], config['image_size'])),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

dataloaders = utils.create_dataloaders(config=config, transforms=transforms_cistos)

model_scratch, _, _, _ = models.create_model(type_model=type_model, description_path=f"{path}/{model_name}_model_params_{dataset_name}.txt", config=config, pre_trained=pre_trained)

n_flops, n_params = utils.count_flops(model_scratch, input_size=(1, 3, config['image_size'], config['image_size']))
print(f"Model: {model_name} - Dataset: {dataset_name}")
print(f"FLOPs: {n_flops} FLOPs")
print(f"Parameters: {n_params} ")
# Out:
# Model: mobilenetv2_scratch - Dataset: cistos
# FLOPs: 283390416.0 FLOPs
# Parameters: 2232839.0

# %%
# Training loop with pre-trained weights
historic_train = trainer.train_loop(config, dataloaders, path, dataset_name, model_name=model_name, type_model=type_model, pre_trained=pre_trained)

# Save training history
with open(f'{path}/{model_name}_historic_{config["dataset_name"]}.json', 'w') as f:
    json.dump(historic_train, f)
# Out:
# Early stopping at epoch 25 for split 1 and percentage 1%
# Early stopping at epoch 25 for split 2 and percentage 1%
# Early stopping at epoch 22 for split 3 and percentage 1%
# Early stopping at epoch 22 for split 1 and percentage 5%
# Early stopping at epoch 43 for split 2 and percentage 5%
# Early stopping at epoch 29 for split 3 and percentage 5%
# Early stopping at epoch 23 for split 1 and percentage 25%
# Early stopping at epoch 41 for split 2 and percentage 25%
# Early stopping at epoch 60 for split 3 and percentage 25%
# Early stopping at epoch 100 for split 1 and percentage 50%
# Early stopping at epoch 71 for split 2 and percentage 50%
# Early stopping at epoch 38 for split 3 and percentage 50%
# Early stopping at epoch 86 for split 1 and percentage 75%
# Early stopping at epoch 57 for split 2 and percentage 75%
# Early stopping at epoch 46 for split 3 and percentage 75%
# Early stopping at epoch 35 for split 1 and percentage 100%
# Early stopping at epoch 53 for split 3 and percentage 100%

# %%
utils.loss_and_accuracy_split(config, path, model_name, show_plot=False)
utils.loss_and_accuracy_aggregate(config, path, model_name, show_plot=False)

results_test = utils.evaluate_test_set(config, path, model_name, dataloaders, type_model=type_model, pre_trained=pre_trained)  

# Save results to JSON
with open(f'{path}/{model_name}_test_results_{config["dataset_name"]}.json', 'w') as f:
    json.dump(results_test, f)

utils.calculate_and_save_reports(config, path, model_name)
# Out:
# Aggregated classification reports saved to mobilenetv2_scratch/cistos/mobilenetv2_scratch_aggregated_classification_report_cistos.txt

# %% [markdown]
# ### Eggs: Pre-trained on ImageNet

# %%
# Configuration for Eggs Dataset

CONFIG_EGG = {
    'dataset_name': 'eggs',
    'split': [1, 2, 3],
    'percentage': [1, 5, 25, 50, 75, 100],
    'num_classes': 9,
    'batch_size': 16,
    'num_workers': 4,
    'image_size': 200,
    'lr': 1e-4,
    'num_epochs': 100,
    'device': 'cuda' if torch.cuda.is_available() else 'cpu'
}

# Create dataloaders
dataset_name = CONFIG_EGG['dataset_name']
model_name = 'squeezenet_pretrained'
type_model = 'squeezenet'
pre_trained = True
path = f"{model_name}/{dataset_name}"
config = CONFIG_EGG
dataloaders = {}

transforms_egg = transforms.Compose([
    transforms.Resize((config['image_size'], config['image_size'])),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

dataloaders = utils.create_dataloaders(config=config, transforms=transforms_egg)

model_scratch, _, _, _ = models.create_model(type_model=type_model, description_path=f"{path}/{model_name}_model_params_{dataset_name}.txt", config=config, pre_trained=pre_trained)

n_flops, n_params = utils.count_flops(model_scratch, input_size=(1, 3, config['image_size'], config['image_size']))
print(f"Model: {model_name} - Dataset: {dataset_name}")
print(f"FLOPs: {n_flops} FLOPs")
print(f"Parameters: {n_params} ")

# %%
# Training loop with pre-trained weights
historic_train = trainer.train_loop(config, dataloaders, path, dataset_name, model_name=model_name, type_model=type_model, pre_trained=pre_trained)

# Save training history
with open(f'{path}/{model_name}_historic_{config["dataset_name"]}.json', 'w') as f:
    json.dump(historic_train, f)

# %%
utils.loss_and_accuracy_split(config, path, model_name, show_plot=False)
utils.loss_and_accuracy_aggregate(config, path, model_name, show_plot=False)

results_test = utils.evaluate_test_set(config, path, model_name, dataloaders, type_model=type_model, pre_trained=pre_trained)  

# Save results to JSON
with open(f'{path}/{model_name}_test_results_{config["dataset_name"]}.json', 'w') as f:
    json.dump(results_test, f)

utils.calculate_and_save_reports(config, path, model_name)

# %% [markdown]
# ### Larvae: Pre-trained on ImageNet

# %%
# Configuration for Larvae Dataset
CONFIG_LARVAE = {
    'dataset_name': 'larvae',
    'split': [1,2,3],
    'percentage': [1, 5, 25, 50, 75, 100],
    'num_classes': 2,
    'batch_size': 16,
    'num_workers': 4,
    'image_size': 200,
    'lr': 1e-4,
    'num_epochs': 100,
    'device': 'cuda' if torch.cuda.is_available() else 'cpu'
}

# Create dataloaders
dataset_name = CONFIG_LARVAE['dataset_name']
model_name = 'squeezenet_pretrained'
type_model = 'squeezenet'
pre_trained = True
path = f"{model_name}/{dataset_name}"
config = CONFIG_LARVAE
dataloaders = {}

transforms_larvae = transforms.Compose([
    transforms.Resize((config['image_size'], config['image_size'])),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

dataloaders = utils.create_dataloaders(config=config, transforms=transforms_larvae)

model_scratch, _, _, _ = models.create_model(type_model=type_model, description_path=f"{path}/{model_name}_model_params_{dataset_name}.txt", config=config, pre_trained=pre_trained)

n_flops, n_params = utils.count_flops(model_scratch, input_size=(1, 3, config['image_size'], config['image_size']))
print(f"Model: {model_name} - Dataset: {dataset_name}")
print(f"FLOPs: {n_flops} FLOPs")
print(f"Parameters: {n_params} ")

# %%
# Training loop with pre-trained weights
historic_train = trainer.train_loop(config, dataloaders, path, dataset_name, model_name=model_name, type_model=type_model, pre_trained=pre_trained)

# Save training history
with open(f'{path}/{model_name}_historic_{config["dataset_name"]}.json', 'w') as f:
    json.dump(historic_train, f)

# %%
utils.loss_and_accuracy_split(config, path, model_name, show_plot=False)
utils.loss_and_accuracy_aggregate(config, path, model_name, show_plot=False)

results_test = utils.evaluate_test_set(config, path, model_name, dataloaders, type_model=type_model, pre_trained=pre_trained)  

# Save results to JSON
with open(f'{path}/{model_name}_test_results_{config["dataset_name"]}.json', 'w') as f:
    json.dump(results_test, f)

utils.calculate_and_save_reports(config, path, model_name)

# %% [markdown]
# ### Cysts: Pre-trained on ImageNet

# %%
# Configuration for Cisto Dataset
CONFIG_CISTO = {
    'dataset_name': 'cistos',
    'split': [1, 2, 3],
    'percentage': [1, 5, 25, 50, 75, 100],
    'num_classes': 7,
    'batch_size': 16,
    'num_workers': 4,
    'image_size': 200,
    'lr': 1e-4,
    'num_epochs': 100,
    'device': 'cuda' if torch.cuda.is_available() else 'cpu'
}

# Create dataloaders
dataset_name = CONFIG_CISTO['dataset_name']
model_name = 'squeezenet_pretrained'
type_model = 'squeezenet'
pre_trained = True
path = f"{model_name}/{dataset_name}"
config = CONFIG_CISTO
dataloaders = {}

transforms_cistos = transforms.Compose([
    transforms.Resize((config['image_size'], config['image_size'])),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

dataloaders = utils.create_dataloaders(config=config, transforms=transforms_cistos)

model_scratch, _, _, _ = models.create_model(type_model=type_model, description_path=f"{path}/{model_name}_model_params_{dataset_name}.txt", config=config, pre_trained=pre_trained)

n_flops, n_params = utils.count_flops(model_scratch, input_size=(1, 3, config['image_size'], config['image_size']))
print(f"Model: {model_name} - Dataset: {dataset_name}")
print(f"FLOPs: {n_flops} FLOPs")
print(f"Parameters: {n_params} ")

# %%
# Training loop with pre-trained weights
historic_train = trainer.train_loop(config, dataloaders, path, dataset_name, model_name=model_name, type_model=type_model, pre_trained=pre_trained)

# Save training history
with open(f'{path}/{model_name}_historic_{config["dataset_name"]}.json', 'w') as f:
    json.dump(historic_train, f)

# %%
utils.loss_and_accuracy_split(config, path, model_name, show_plot=False)
utils.loss_and_accuracy_aggregate(config, path, model_name, show_plot=False)

results_test = utils.evaluate_test_set(config, path, model_name, dataloaders, type_model=type_model, pre_trained=pre_trained)  

# Save results to JSON
with open(f'{path}/{model_name}_test_results_{config["dataset_name"]}.json', 'w') as f:
    json.dump(results_test, f)

utils.calculate_and_save_reports(config, path, model_name)
